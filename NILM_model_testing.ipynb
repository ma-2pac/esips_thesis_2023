# %% [markdown]
# <a href="https://colab.research.google.com/github/ma-2pac/esips_thesis_2023/blob/main/NILM_model_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/gdrive/MyDrive/ESIPS/Datasets/ukdale.zip
# Out:
# Archive:  /content/gdrive/MyDrive/ESIPS/Datasets/ukdale.zip
#   inflating: house_1/channel_10_button_press.dat
#   inflating: house_1/channel_10.dat
#   inflating: house_1/channel_11_button_press.dat
#   inflating: house_1/channel_11.dat
#   inflating: house_1/channel_12_button_press.dat
#   inflating: house_1/channel_12.dat
#   inflating: house_1/channel_13_button_press.dat
#   inflating: house_1/channel_13.dat
#   inflating: house_1/channel_14_button_press.dat
#   inflating: house_1/channel_14.dat
#   inflating: house_1/channel_15_button_press.dat
#   inflating: house_1/channel_15.dat
#   inflating: house_1/channel_16_button_press.dat
#   inflating: house_1/channel_16.dat
#   inflating: house_1/channel_17_button_press.dat
#   inflating: house_1/channel_17.dat
#   inflating: house_1/channel_18_button_press.dat
#   inflating: house_1/channel_18.dat
#   inflating: house_1/channel_19_button_press.dat
#   inflating: house_1/channel_19.dat
#   inflating: house_1/channel_1.dat
# ...
